# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://datahub.io/core/finance-vix/r/0.html")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-3-7065f8504c38> in <cell line: 1>()
# ----> 1 df = pd.read_csv("https://datahub.io/core/finance-vix/r/0.html")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
plt.hist(df['VIX Close'])
plt.xlabel('VIX CLOSE Values')
plt.ylabel('# of Instances')
plt.show()

# %%
df.head()
# Out:
#          Date  VIX Open  VIX High  VIX Low  VIX Close
# 0  2004-01-02     17.96     18.68    17.54      18.22
# 1  2004-01-05     18.45     18.49    17.44      17.49
# 2  2004-01-06     17.66     17.67    16.19      16.73
# 3  2004-01-07     16.72     16.75    15.50      15.50
# 4  2004-01-08     15.42     15.68    15.32      15.61
